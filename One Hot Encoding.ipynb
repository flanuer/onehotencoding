# %%
import pandas as pd
import numpy as np
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %%
data = pd.read_csv("/home/scott/Desktop/betterlabels/haedat_search.csv",encoding = "ISO-8859-1")

# %%
data.sample(5)
# Out:
#       eventName  eventYear                         region originalGridCode  \
# 4809  IE-06-002       2006                          IRL W              NaN
# 120   UY-13-001       2013                          Rocha              NaN
# 7852  BR-09-007       2009                            NaN              NaN
# 4699  IE-99-001       1999  Donegal, North Coast Ireland.              NaN
# 5376  FR-98-035       1998                            NaN              NaN
#
#       monitoringProgramme                                      programmeName  \
# 4809                    1  National Monitoring Programme for marine bioto...
# 120                     1  National Monitoring Program of Harmful Phytopl...
# 7852                    0                                                NaN
# 4699                    1  Shellfish Toxicity Monitoring Program for Irel...
# 5376                    1                                              REPHY
#
# ...

# %%
for col in data.columns:
    print(col, ': ', len(data[col].unique()), 'labels')
# Out:
# eventName :  7818 labels
# eventYear :  72 labels
# region :  1283 labels
# originalGridCode :  98 labels
# monitoringProgramme :  2 labels
# programmeName :  602 labels
# occurredBefore :  3 labels
# occurredBeforeText :  1231 labels
# waterDiscoloration :  2 labels
# highPhyto :  2 labels
# seafoodToxin :  2 labels
# massMortal :  2 labels
# foamMucil :  2 labels
# otherEffect :  2 labels
# otherEffectText :  111 labels
# days :  36 labels
# months :  15 labels
# locationText :  3730 labels
# latitude :  1374 labels
# longitude :  1366 labels
# additionalLocationInfo :  1598 labels
# eventDate :  1939 labels
# initialDate :  2254 labels
# finalDate :  2088 labels
# quarantineStartDate :  1565 labels
# quarantineEndDate :  1377 labels
# additionalDateInfo :  1441 labels
# causativeKnown :  2 labels
# pigmentAnalysisInfo :  207 labels
# additionalAlgaeInfo :  706 labels
# toxicityDetected :  2 labels
# toxicityRange :  1847 labels
# humansAffected :  2 labels
# ...
